# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import tensorflow as tf
from sklearn.linear_model import LogisticRegression
# Out:
# 2023-12-08 21:30:02.853500: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-08 21:30:02.853566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-08 21:30:03.255948: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-08 21:30:04.072204: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from tqdm import tqdm

# %%
from sklearnex.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn import svm, datasets
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.metrics import roc_curve, auc
from scipy import interp
from itertools import cycle

# %%
# !pip install tensorflow

# %%
process_df = pd.read_csv('process_df.csv')
review_features = pd.read_csv('review_features.csv')

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000,ngram_range=(2,2))

X= tfidf_vectorizer.fit_transform(review_features['reviews_all'])

# %%
y=process_df['sentiment']

# %%
param_grid = [{'C': np.logspace(-4, 4, 10),
              'penalty': ['l1', 'l2']}]

# Create the Logistic Regression model
logreg = LogisticRegression(random_state=0)

clf = GridSearchCV(logreg, param_grid, cv=5, verbose=0, n_jobs=-1)

best_clf = clf.fit(X,y)

# Get the best model and its accuracy
best_model = clf.best_estimator_
accuracy = best_model.score(X_test, y_test)

print("Best Model:", best_model)
print("Best Model Accuracy:", accuracy)
# Out:
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
param_grid = [{'C': np.logspace(-2, 2, 10),
              'penalty': ['l1', 'l2']}]

# Create the Logistic Regression model
logreg = LogisticRegression(random_state=0)

clf = GridSearchCV(logreg, param_grid, cv=5, verbose=0, n_jobs=-1)

best_clf = clf.fit(X,y)

# Get the best model and its accuracy
best_model = clf.best_estimator_
accuracy = best_model.score(X_test, y_test)

print("Best Model:", best_model)
print("Best Model Accuracy:", accuracy)
# Out:
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
best_model
# Out:
# LogisticRegression(C=0.5994842503189409, random_state=0)

# %%
logreg = LogisticRegression(C=0.5994842, random_state=0)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.84
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i in range (cm.shape[0]):
        for j in range (cm.shape[1]):
            plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm = metrics.confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm, classes=['Negative','Neutral','Positive'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ## balcance the labels

# %%
print(f'Original dataset shape : {Counter(y)}')

smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

print(f'Resampled dataset shape {Counter(y_res)}')
# Out:
# Original dataset shape : Counter({2: 313243, 0: 67543, 1: 31467})
# Resampled dataset shape Counter({2: 313243, 1: 313243, 0: 313243})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=0)

# %%
param_grid = [{'C': np.logspace(-4, 4, 10),
              'penalty': ['l1', 'l2']}]

class_counts = np.bincount(y_train)
class_weights = {class_label: len(y_train) / (len(class_label) * class_count) for class_label, class_count in enumerate(class_counts)}


# Create the Logistic Regression model
logreg = LogisticRegression(random_state=0, class_weight = class_weights)

clf = GridSearchCV(logreg, param_grid, cv=5, verbose=0, n_jobs=-1)

best_clf = clf.fit(X_train,y_train)

# Get the best model and its accuracy
best_model = clf.best_estimator_
accuracy = best_model.score(X_test, y_test)

print("Best Model:", best_model)
print("Best Model Accuracy:", accuracy)
# Out:
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
X_train_, X_test_, y_train_, y_test_ = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
y_train_.value_counts()
# Out:
# 2    250492
# 0     54125
# 1     25185
# Name: sentiment, dtype: int64

# %%
len(y_train_.value_counts())
# Out:
# 3

# %%
y_train_.value_counts().index
# Out:
# Int64Index([2, 0, 1], dtype='int64')

# %%
for i,j  in zip(y_train_.value_counts().index, y_train_.value_counts()):
    print(i)
    print(j)
# Out:
# 2
# 250492
# 0
# 54125
# 1
# 25185

# %%
param_grid = [{'C': np.logspace(-4, 4, 10),
              'penalty': ['l1', 'l2']}]

class_counts = y_train_.value_counts()

class_weights = {class_label: (len(y_train_) / ((len(y_train_.value_counts()) * class_count))) for class_label, class_count in zip(y_train_.value_counts().index, y_train_.value_counts())}
print(class_weights)
# Out:
# {2: 0.4388722993149482, 0: 2.0311131639722864, 1: 4.365058566607107}

# %%
# Create the Logistic Regression model
logreg = LogisticRegression(random_state=0, class_weight = class_weights)

clf = GridSearchCV(logreg, param_grid, cv=5, verbose=0, n_jobs=-1)

best_clf = clf.fit(X_train_,y_train_)

# Get the best model and its accuracy
best_model = clf.best_estimator_
accuracy = best_model.score(X_test_, y_test_)

print("Best Model:", best_model)
print("Best Model Accuracy:", accuracy)
# Out:
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /sw/pkgs/arc/python3.10-anaconda/2023.03/lib/python3.10/site-packages/daal4py/sklearn/linear_model/logistic_path.py:574: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
best_model
# Out:
# LogisticRegression(C=0.0001,
#                    class_weight={0: 2.0311131639722864, 1: 4.365058566607107,
#                                  2: 0.4388722993149482},
#                    random_state=0)

# %%
logreg = LogisticRegression(C=0.0001,class_weight={0: 2.0311131639722864, 1: 4.3650585666071, 2: 0.4388722993149482}, random_state=0, multi_class='ovr')
logreg.fit(X_train_, y_train_)
y_pred_ = logreg.predict(X_test_)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test_, y_test_)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.76

# %%
cm = metrics.confusion_matrix(y_test_, y_pred_)
plot_confusion_matrix(cm, classes=['Negative','Neutral','Positive'])
# Out:
# Confusion matrix, without normalization

# %%
print("Classification Report:\n",classification_report(y_test_, y_pred_))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.53      0.57     13418
#            1       0.23      0.44      0.30      6282
#            2       0.89      0.84      0.87     62751
#
#     accuracy                           0.76     82451
#    macro avg       0.58      0.60      0.58     82451
# weighted avg       0.80      0.76      0.78     82451

# %%
y_pred_.shape
# Out:
# (82451,)

# %%
type(y_test_)
# Out:
# pandas.core.series.Series

# %%
len(y_test_.tolist())
# Out:
# 82451

# %%
#Binarizing the target feature
y = label_binarize(y, classes=[0, 1, 2])
n_classes = y.shape[1]
#Train-Test split(80:20)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2,
                                                    random_state=0)

# %%
np.sum(y, axis=0)
# Out:
# array([ 67543,  31467, 313243])

# %%
from sklearn.svm import LinearSVC

classifier = OneVsRestClassifier(LinearSVC(random_state=10), n_jobs=-1)
y_score = classifier.fit(X_train_, y_train_).decision_function(X_test_)

# %%
# #OneVsRestClassifier
# classifier = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True,
#                                  random_state=10))
# y_score = classifier.fit(X_train, y_train).decision_function(X_test)

#Computing TPR and FPR
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    
# aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# %%
# interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in tqdm(range(n_classes)):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=4,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]/tmp/ipykernel_1272048/1781115617.py:4: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])
# 100%|██████████| 3/3 [00:00<00:00, 1815.19it/s]

# %% [markdown]
# ## class 0 -- Negative; class 1 -- Neutral; class 2 -- Positive

# %% [markdown]
# ## random forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier
rf_classifier.fit(X_train_, y_train_)

# Make predictions on the test set
y_pred = rf_classifier.predict(X_test_)

# %%
rf_classifier
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred
# Out:
# array([2, 2, 2, ..., 0, 2, 2])

# %%
accuracy = accuracy_score(y_test_, y_pred)
conf_matrix = confusion_matrix(y_test_, y_pred)
classification_rep = classification_report(y_test_, y_pred)

# %%
accuracy
# Out:
# 0.8400261973778366

# %%
conf_matrix
# Out:
# array([[ 7758,   172,  5488],
#        [ 1113,  1104,  4065],
#        [ 2059,   293, 60399]])

# %% [markdown]
# ## I guess we still need the class balance stuff so don't wanna continue on exploring random forest anymore
